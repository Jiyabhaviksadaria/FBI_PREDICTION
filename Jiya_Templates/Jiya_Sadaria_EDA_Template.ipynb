# %% [markdown]
# # **Jiya Sadaria – EDA Submission**

# %% [markdown]
# ## Author
# - **Name:** Jiya Sadaria

# %% [markdown]
# # **Project Summary**
# - Write your summary here (500‑600 words).

# %% [markdown]
# # **General Guidelines**
# 1. Well‑structured, formatted, and commented code.
# 2. Exception handling and production‑grade code.
# 3. Add as many charts as needed, answering the required questions for each.

# %% [markdown]
# # ***Let's Begin!***

# %% [markdown]
# ## 1. Know Your Data

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Dark mode styling
plt.style.use('dark_background')
sns.set_theme(style='darkgrid')

# %% [markdown]
# ### Dataset Loading

# %%
# Load your dataset
# df = pd.read_csv('path/to/your/data.csv')

# %% [markdown]
# ### Initial Data Inspection

# %%
# Show first rows
# df.head()

# %% [markdown]
# ### Data Wrangling
# - Perform any cleaning, missing value handling, etc.

# %%
# Example: Drop duplicates
# df = df.drop_duplicates()

# %% [markdown]
# ### Visualization (UBM Rule)
# #### Chart 1
# * Why this chart?
# * Insight(s) found?
# * Business impact?

# %%
# Chart 1 example
# fig = px.histogram(df, x='column_name')
# fig.show()
